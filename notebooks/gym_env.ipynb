# %%
from load_data import load_data
from add_reward import add_reward_df

# %%
df = load_data()
df = add_reward_df(df)

# %%
df = df.reset_index()

# %%
min_values = df.describe().loc['min']
max_values = df.describe().loc['max']

# %%
min_observation= min_values.loc[~min_values.index.isin(['SepsisLabel',
                                                        'patient', 
                                                        'zeros_reward',
                                                        'ones_reward'])].min()

max_observation = max_values.loc[~max_values.index.isin(['SepsisLabel',
                                                         'patient',
                                                         'zeros_reward',
                                                         'ones_reward'])].max()

# %%
min_observation
# Out:
# -25.545204389483803

# %%
max_observation
# Out:
# 335.0

# %%
import random
import json
import gym
from gym import spaces
import pandas as pd
import numpy as np


class SepsisEnv(gym.Env):
    """A Sepsis environment for OpenAI gym"""
    metadata = {'render.modes': ['human']}
    
    def __init__(self, df):
        super(SepsisEnv, self).__init__()

        self.df = df
        self.reward_range = (-2.0, 1.0)
        # Only two possible actions, 0 for non-sepsis,
        # 1 for sepsis.
        n_actions = 2
        self.action_space = spaces.Discrete(n=n_actions)
        # Observation space is a feature vector of 41 vital signs, 
        # lab values, and other demographic information.
        self.observation_space = spaces.Box(
            low=-25.545204389483803, high=335.0, shape=(1, 42), dtype=np.float16)

    def _next_observation(self):
        obs = np.array([
        self.df.loc[self.current_step, ~df.columns.isin(['SepsisLabel',
                            'patient', 
                            'zeros_reward',
                            'ones_reward'])].values 

        ])

        return obs


    def step(self, action):
        # Execute one time step within the environment
        self.current_step += 1
        
        if action == 0:
            reward = self.df.loc[self.current_step, ['zeros_reward']]
        else:
            reward = self.df.loc[self.current_step, ['ones_reward']]

        done = False

        obs = self._next_observation()

        return obs, reward, done, {}

    def reset(self):
        # Reset the state of the environment to an initial state

        # Set the current step to a random point within the data frame
        self.current_step = random.randint(
            0, len(self.df.loc[:, 'HR'].values))

        return self._next_observation()

    def render(self, mode='human', close=False):
        # Render the environment to the screen
        print('current step' ,self.current_step)

# %%
import gym
import json
import datetime as dt
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2
import pandas as pd

# %%
env = DummyVecEnv([lambda: SepsisEnv(df)])
model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=20000)
obs = env.reset()
for i in range(2000):
  action, _states = model.predict(obs)
  obs, rewards, done, info = env.step(action)
  env.render()
# Out:
# WARNING:tensorflow:From /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:191: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/stable_baselines/common/tf_util.py:200: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/stable_baselines/common/policies.py:116: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/stable_baselines/common/input.py:25: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/stable_baselines/common/policies.py:561: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f606ae3ead0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f606ae3ead0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f606ae3ead0>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f606ae3ead0>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/stable_baselines/common/tf_layers.py:123: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f602c58cf50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f602c58cf50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f602c58cf50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f602c58cf50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:From /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:190: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:206: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/stable_baselines/ppo2/ppo2.py:242: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# --------------------------------------
# | approxkl           | 0.0005859758  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.04         |
# | fps                | 235           |
# | n_updates          | 1             |
# | policy_entropy     | 0.6925658     |
# | policy_loss        | -0.0029517147 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 1.19e-05      |
# | total_timesteps    | 128           |
# | value_loss         | 0.06827691    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.0007327878   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0984        |
# | fps                | 574            |
# | n_updates          | 2              |
# | policy_entropy     | 0.687957       |
# | policy_loss        | -0.00033928873 |
# | serial_timesteps   | 256            |
# | time_elapsed       | 0.546          |
# | total_timesteps    | 256            |
# | value_loss         | 0.20107943     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 5.9040118e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.03           |
# | fps                | 573            |
# | n_updates          | 3              |
# | policy_entropy     | 0.68211937     |
# | policy_loss        | -0.00011366606 |
# | serial_timesteps   | 384            |
# | time_elapsed       | 0.769          |
# | total_timesteps    | 384            |
# | value_loss         | 0.21768324     |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0013284227 |
# | clipfrac           | 0.0          |
# | explained_variance | -6.56        |
# | fps                | 550          |
# | n_updates          | 4            |
# | policy_entropy     | 0.67552924   |
# | policy_loss        | -0.007875662 |
# | serial_timesteps   | 512          |
# | time_elapsed       | 0.993        |
# | total_timesteps    | 512          |
# | value_loss         | 0.032822344  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0027239602  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.332        |
# | fps                | 565           |
# | n_updates          | 5             |
# | policy_entropy     | 0.6394952     |
# | policy_loss        | -0.0033220402 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 1.23          |
# | total_timesteps    | 640           |
# | value_loss         | 0.05378316    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0049194675 |
# | clipfrac           | 0.060546875  |
# | explained_variance | -0.17        |
# | fps                | 551          |
# | n_updates          | 6            |
# | policy_entropy     | 0.57853466   |
# | policy_loss        | -0.019637313 |
# | serial_timesteps   | 768          |
# | time_elapsed       | 1.45         |
# | total_timesteps    | 768          |
# | value_loss         | 0.002658309  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0008133447  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0108        |
# | fps                | 531           |
# | n_updates          | 7             |
# | policy_entropy     | 0.511891      |
# | policy_loss        | -0.0014640411 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 1.69          |
# | total_timesteps    | 896           |
# | value_loss         | 2.0365014     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0016796957 |
# | clipfrac           | 0.001953125  |
# | explained_variance | -15.5        |
# | fps                | 509          |
# | n_updates          | 8            |
# | policy_entropy     | 0.51291096   |
# | policy_loss        | -0.011522139 |
# | serial_timesteps   | 1024         |
# | time_elapsed       | 1.93         |
# | total_timesteps    | 1024         |
# | value_loss         | 0.03519468   |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00076092605 |
# | clipfrac           | 0.0           |
# | explained_variance | -21.1         |
# | fps                | 530           |
# | n_updates          | 9             |
# | policy_entropy     | 0.45643207    |
# | policy_loss        | -0.005715921  |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 2.18          |
# | total_timesteps    | 1152          |
# | value_loss         | 0.042638525   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005644725  |
# | clipfrac           | 0.0           |
# | explained_variance | -18.5         |
# | fps                | 518           |
# | n_updates          | 10            |
# | policy_entropy     | 0.4242148     |
# | policy_loss        | -0.0060725035 |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 2.42          |
# | total_timesteps    | 1280          |
# | value_loss         | 0.02453394    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00086887117 |
# | clipfrac           | 0.0           |
# | explained_variance | -10.1         |
# | fps                | 494           |
# | n_updates          | 11            |
# | policy_entropy     | 0.37656265    |
# | policy_loss        | -0.005211845  |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 2.67          |
# | total_timesteps    | 1408          |
# | value_loss         | 0.025385609   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0017045552 |
# | clipfrac           | 0.02734375   |
# | explained_variance | -4.91        |
# | fps                | 547          |
# | n_updates          | 12           |
# | policy_entropy     | 0.33529472   |
# | policy_loss        | -0.01226124  |
# | serial_timesteps   | 1536         |
# | time_elapsed       | 2.93         |
# | total_timesteps    | 1536         |
# | value_loss         | 0.015571825  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00063191046 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.11         |
# | fps                | 494           |
# | n_updates          | 13            |
# | policy_entropy     | 0.2755679     |
# | policy_loss        | -0.004305894  |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 3.17          |
# | total_timesteps    | 1664          |
# | value_loss         | 0.0071847616  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00016275821 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0046       |
# | fps                | 559           |
# | n_updates          | 14            |
# | policy_entropy     | 0.25902104    |
# | policy_loss        | 0.00047413295 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 3.43          |
# | total_timesteps    | 1792          |
# | value_loss         | 2.6536841     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 2.509456e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -4.45        |
# | fps                | 518          |
# | n_updates          | 15           |
# | policy_entropy     | 0.24939953   |
# | policy_loss        | -0.00184217  |
# | serial_timesteps   | 1920         |
# | time_elapsed       | 3.66         |
# | total_timesteps    | 1920         |
# | value_loss         | 0.009957566  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.000711952  |
# | clipfrac           | 0.00390625   |
# | explained_variance | -9.86        |
# | fps                | 502          |
# | n_updates          | 16           |
# | policy_entropy     | 0.21481311   |
# | policy_loss        | -0.011707054 |
# | serial_timesteps   | 2048         |
# | time_elapsed       | 3.9          |
# | total_timesteps    | 2048         |
# | value_loss         | 0.006695323  |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 5.5973484e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -1.34          |
# | fps                | 563            |
# | n_updates          | 17             |
# | policy_entropy     | 0.18774843     |
# | policy_loss        | -0.00036264607 |
# | serial_timesteps   | 2176           |
# | time_elapsed       | 4.16           |
# | total_timesteps    | 2176           |
# | value_loss         | 0.006487748    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.9022324e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -11.1         |
# | fps                | 484           |
# | n_updates          | 18            |
# | policy_entropy     | 0.2004563     |
# | policy_loss        | -0.0014453674 |
# | serial_timesteps   | 2304          |
# | time_elapsed       | 4.39          |
# | total_timesteps    | 2304          |
# | value_loss         | 0.0079472     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 4.86375e-05  |
# | clipfrac           | 0.0          |
# | explained_variance | -13.1        |
# | fps                | 511          |
# | n_updates          | 19           |
# | policy_entropy     | 0.1964031    |
# | policy_loss        | -0.001979966 |
# | serial_timesteps   | 2432         |
# | time_elapsed       | 4.65         |
# | total_timesteps    | 2432         |
# | value_loss         | 0.0072071073 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 2.8777378e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -13.2         |
# | fps                | 472           |
# | n_updates          | 20            |
# | policy_entropy     | 0.2139101     |
# | policy_loss        | -0.0011249336 |
# | serial_timesteps   | 2560          |
# | time_elapsed       | 4.9           |
# | total_timesteps    | 2560          |
# | value_loss         | 0.005881757   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.172673e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -4.85         |
# | fps                | 495           |
# | n_updates          | 21            |
# | policy_entropy     | 0.19480592    |
# | policy_loss        | -0.0007376095 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 5.17          |
# | total_timesteps    | 2688          |
# | value_loss         | 0.004827988   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.3932165e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0118        |
# | fps                | 527            |
# | n_updates          | 22             |
# | policy_entropy     | 0.1906433      |
# | policy_loss        | -3.4204568e-05 |
# | serial_timesteps   | 2816           |
# | time_elapsed       | 5.43           |
# | total_timesteps    | 2816           |
# | value_loss         | 1.7859578      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.669999e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -5.21         |
# | fps                | 521           |
# | n_updates          | 23            |
# | policy_entropy     | 0.18887925    |
# | policy_loss        | -0.0018862044 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 5.68          |
# | total_timesteps    | 2944          |
# | value_loss         | 0.0047609783  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 6.392157e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -1.66        |
# | fps                | 503          |
# | n_updates          | 24           |
# | policy_entropy     | 0.17526779   |
# | policy_loss        | -0.002283637 |
# | serial_timesteps   | 3072         |
# | time_elapsed       | 5.92         |
# | total_timesteps    | 3072         |
# | value_loss         | 0.0041683507 |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 0.000111912486 |
# | clipfrac           | 0.0            |
# | explained_variance | -1.64          |
# | fps                | 568            |
# | n_updates          | 25             |
# | policy_entropy     | 0.18156254     |
# | policy_loss        | -0.004495938   |
# | serial_timesteps   | 3200           |
# | time_elapsed       | 6.18           |
# | total_timesteps    | 3200           |
# | value_loss         | 0.004929479    |
# ---------------------------------------
# -------------------------------------
# | approxkl           | 0.0004320044 |
# | clipfrac           | 0.005859375  |
# | explained_variance | -8.11        |
# | fps                | 590          |
# | n_updates          | 26           |
# | policy_entropy     | 0.16622108   |
# | policy_loss        | -0.00820413  |
# | serial_timesteps   | 3328         |
# | time_elapsed       | 6.4          |
# | total_timesteps    | 3328         |
# | value_loss         | 0.005887539  |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 4.4406985e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -5.65          |
# | fps                | 525            |
# | n_updates          | 27             |
# | policy_entropy     | 0.16878814     |
# | policy_loss        | -0.00057377154 |
# | serial_timesteps   | 3456           |
# | time_elapsed       | 6.62           |
# | total_timesteps    | 3456           |
# | value_loss         | 0.006950955    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.3672439e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.01         |
# | fps                | 502           |
# | n_updates          | 28            |
# | policy_entropy     | 0.16748255    |
# | policy_loss        | -0.0022074932 |
# | serial_timesteps   | 3584          |
# | time_elapsed       | 6.87          |
# | total_timesteps    | 3584          |
# | value_loss         | 0.0030677936  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00015746904 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.53         |
# | fps                | 492           |
# | n_updates          | 29            |
# | policy_entropy     | 0.1497963     |
# | policy_loss        | -0.004669139  |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 7.12          |
# | total_timesteps    | 3712          |
# | value_loss         | 0.0044891     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00035669334 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -0.0994       |
# | fps                | 516           |
# | n_updates          | 30            |
# | policy_entropy     | 0.14520553    |
# | policy_loss        | -0.0054184776 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 7.38          |
# | total_timesteps    | 3840          |
# | value_loss         | 0.005134602   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.238783e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0178       |
# | fps                | 514           |
# | n_updates          | 31            |
# | policy_entropy     | 0.14401193    |
# | policy_loss        | 1.7943676e-05 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 7.63          |
# | total_timesteps    | 3968          |
# | value_loss         | 1.4246595     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 7.251513e-05 |
# | clipfrac           | 0.0          |
# | explained_variance | -3.65        |
# | fps                | 558          |
# | n_updates          | 32           |
# | policy_entropy     | 0.09771021   |
# | policy_loss        | -0.00424005  |
# | serial_timesteps   | 4096         |
# | time_elapsed       | 7.88         |
# | total_timesteps    | 4096         |
# | value_loss         | 0.0047984137 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 5.2410873e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -11.4         |
# | fps                | 551           |
# | n_updates          | 33            |
# | policy_entropy     | 0.10340966    |
# | policy_loss        | -0.0016186691 |
# | serial_timesteps   | 4224          |
# | time_elapsed       | 8.11          |
# | total_timesteps    | 4224          |
# | value_loss         | 0.003618056   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 9.8210396e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -8.03         |
# | fps                | 563           |
# | n_updates          | 34            |
# | policy_entropy     | 0.10359428    |
# | policy_loss        | -0.0049989223 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 8.34          |
# | total_timesteps    | 4352          |
# | value_loss         | 0.0035743683  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.8405502e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.652        |
# | fps                | 536           |
# | n_updates          | 35            |
# | policy_entropy     | 0.08391886    |
# | policy_loss        | -0.0018627133 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 8.57          |
# | total_timesteps    | 4480          |
# | value_loss         | 0.013387886   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.624597e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00118       |
# | fps                | 555           |
# | n_updates          | 36            |
# | policy_entropy     | 0.090445906   |
# | policy_loss        | -0.0001855169 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 8.81          |
# | total_timesteps    | 4608          |
# | value_loss         | 0.86525303    |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0008999192 |
# | clipfrac           | 0.013671875  |
# | explained_variance | -1.32        |
# | fps                | 534          |
# | n_updates          | 37           |
# | policy_entropy     | 0.08602254   |
# | policy_loss        | -0.009025864 |
# | serial_timesteps   | 4736         |
# | time_elapsed       | 9.04         |
# | total_timesteps    | 4736         |
# | value_loss         | 0.0034638986 |
# -------------------------------------
# -------------------------------------
# | approxkl           | 7.82946e-07  |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0178       |
# | fps                | 497          |
# | n_updates          | 38           |
# | policy_entropy     | 0.051578354  |
# | policy_loss        | 2.080074e-05 |
# | serial_timesteps   | 4864         |
# | time_elapsed       | 9.28         |
# | total_timesteps    | 4864         |
# | value_loss         | 2.7956407    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.00038269866 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -2.33         |
# | fps                | 536           |
# | n_updates          | 39            |
# | policy_entropy     | 0.07341072    |
# | policy_loss        | -0.0069950097 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 9.54          |
# | total_timesteps    | 4992          |
# | value_loss         | 0.007315814   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 6.7754518e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.78         |
# | fps                | 490           |
# | n_updates          | 40            |
# | policy_entropy     | 0.06664222    |
# | policy_loss        | 4.5872875e-05 |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 9.78          |
# | total_timesteps    | 5120          |
# | value_loss         | 0.006197095   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.1521976e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.55         |
# | fps                | 511           |
# | n_updates          | 41            |
# | policy_entropy     | 0.06465536    |
# | policy_loss        | -0.0029934202 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 10            |
# | total_timesteps    | 5248          |
# | value_loss         | 0.004199578   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.131855e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -15.2         |
# | fps                | 561           |
# | n_updates          | 42            |
# | policy_entropy     | 0.0775642     |
# | policy_loss        | -0.0036097325 |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 10.3          |
# | total_timesteps    | 5376          |
# | value_loss         | 0.0038010534  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.3219941e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -8.15         |
# | fps                | 549           |
# | n_updates          | 43            |
# | policy_entropy     | 0.073386356   |
# | policy_loss        | -0.001955037  |
# | serial_timesteps   | 5504          |
# | time_elapsed       | 10.5          |
# | total_timesteps    | 5504          |
# | value_loss         | 0.0036316258  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.7096276e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -5.28          |
# | fps                | 549            |
# | n_updates          | 44             |
# | policy_entropy     | 0.06837256     |
# | policy_loss        | -0.00061274786 |
# | serial_timesteps   | 5632           |
# | time_elapsed       | 10.8           |
# | total_timesteps    | 5632           |
# | value_loss         | 0.007045415    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.7016842e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0306        |
# | fps                | 512           |
# | n_updates          | 45            |
# | policy_entropy     | 0.055318274   |
# | policy_loss        | 0.00014929834 |
# | serial_timesteps   | 5760          |
# | time_elapsed       | 11            |
# | total_timesteps    | 5760          |
# | value_loss         | 2.6785564     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.4434923e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0826        |
# | fps                | 518           |
# | n_updates          | 46            |
# | policy_entropy     | 0.05102122    |
# | policy_loss        | -6.382633e-05 |
# | serial_timesteps   | 5888          |
# | time_elapsed       | 11.2          |
# | total_timesteps    | 5888          |
# | value_loss         | 0.2890514     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.6034648e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0748        |
# | fps                | 525           |
# | n_updates          | 47            |
# | policy_entropy     | 0.06805308    |
# | policy_loss        | -0.0005157655 |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 11.5          |
# | total_timesteps    | 6016          |
# | value_loss         | 0.11838775    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.0791259e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0586         |
# | fps                | 553            |
# | n_updates          | 48             |
# | policy_entropy     | 0.061368845    |
# | policy_loss        | -0.00024480722 |
# | serial_timesteps   | 6144           |
# | time_elapsed       | 11.7           |
# | total_timesteps    | 6144           |
# | value_loss         | 2.5468252      |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.0352464e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.715         |
# | fps                | 520            |
# | n_updates          | 49             |
# | policy_entropy     | 0.05697591     |
# | policy_loss        | -0.00083805574 |
# | serial_timesteps   | 6272           |
# | time_elapsed       | 12             |
# | total_timesteps    | 6272           |
# | value_loss         | 0.006739695    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 7.099954e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.811         |
# | fps                | 531            |
# | n_updates          | 50             |
# | policy_entropy     | 0.052433435    |
# | policy_loss        | -0.00094304094 |
# | serial_timesteps   | 6400           |
# | time_elapsed       | 12.2           |
# | total_timesteps    | 6400           |
# | value_loss         | 0.010503508    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00031392922 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -13.2         |
# | fps                | 483           |
# | n_updates          | 51            |
# | policy_entropy     | 0.05186662    |
# | policy_loss        | -0.0063915625 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 12.5          |
# | total_timesteps    | 6528          |
# | value_loss         | 0.0037123845  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00010616351 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.45         |
# | fps                | 490           |
# | n_updates          | 52            |
# | policy_entropy     | 0.042068433   |
# | policy_loss        | -0.0033567823 |
# | serial_timesteps   | 6656          |
# | time_elapsed       | 12.7          |
# | total_timesteps    | 6656          |
# | value_loss         | 0.0034653307  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.8055367e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.207         |
# | fps                | 527            |
# | n_updates          | 53             |
# | policy_entropy     | 0.035385724    |
# | policy_loss        | 0.000118615804 |
# | serial_timesteps   | 6784           |
# | time_elapsed       | 13             |
# | total_timesteps    | 6784           |
# | value_loss         | 0.0031699287   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.422289e-06  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00701       |
# | fps                | 507           |
# | n_updates          | 54            |
# | policy_entropy     | 0.039834596   |
# | policy_loss        | 0.00011793722 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 13.2          |
# | total_timesteps    | 6912          |
# | value_loss         | 1.7528596     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.1153252e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -4.68         |
# | fps                | 486           |
# | n_updates          | 55            |
# | policy_entropy     | 0.034991257   |
# | policy_loss        | -0.0005184921 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 13.5          |
# | total_timesteps    | 7040          |
# | value_loss         | 0.0046974504  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00020219867 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -13.3         |
# | fps                | 525           |
# | n_updates          | 56            |
# | policy_entropy     | 0.040290736   |
# | policy_loss        | -0.0032084137 |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 13.7          |
# | total_timesteps    | 7168          |
# | value_loss         | 0.0033747766  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.314169e-07   |
# | clipfrac           | 0.0            |
# | explained_variance | -14.8          |
# | fps                | 522            |
# | n_updates          | 57             |
# | policy_entropy     | 0.027788095    |
# | policy_loss        | -0.00028051657 |
# | serial_timesteps   | 7296           |
# | time_elapsed       | 14             |
# | total_timesteps    | 7296           |
# | value_loss         | 0.0024054847   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 4.784942e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | -4.7           |
# | fps                | 502            |
# | n_updates          | 58             |
# | policy_entropy     | 0.026047805    |
# | policy_loss        | -6.0042134e-05 |
# | serial_timesteps   | 7424           |
# | time_elapsed       | 14.2           |
# | total_timesteps    | 7424           |
# | value_loss         | 0.0017577632   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.496384e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -8.75         |
# | fps                | 511           |
# | n_updates          | 59            |
# | policy_entropy     | 0.024660956   |
# | policy_loss        | -0.0002661359 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 14.5          |
# | total_timesteps    | 7552          |
# | value_loss         | 0.0016101969  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.3360752e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0225         |
# | fps                | 500            |
# | n_updates          | 60             |
# | policy_entropy     | 0.028699094    |
# | policy_loss        | -0.00070426567 |
# | serial_timesteps   | 7680           |
# | time_elapsed       | 14.7           |
# | total_timesteps    | 7680           |
# | value_loss         | 0.009982053    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.524259e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00461       |
# | fps                | 509           |
# | n_updates          | 61            |
# | policy_entropy     | 0.051414732   |
# | policy_loss        | -0.0003767755 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 15            |
# | total_timesteps    | 7808          |
# | value_loss         | 1.7191985     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.8337752e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.36         |
# | fps                | 520           |
# | n_updates          | 62            |
# | policy_entropy     | 0.03312285    |
# | policy_loss        | -0.0020010471 |
# | serial_timesteps   | 7936          |
# | time_elapsed       | 15.2          |
# | total_timesteps    | 7936          |
# | value_loss         | 0.002552129   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.9194417e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0216         |
# | fps                | 548            |
# | n_updates          | 63             |
# | policy_entropy     | 0.030969087    |
# | policy_loss        | -5.2925083e-05 |
# | serial_timesteps   | 8064           |
# | time_elapsed       | 15.5           |
# | total_timesteps    | 8064           |
# | value_loss         | 2.5990767      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 6.0480288e-05 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -1.74         |
# | fps                | 523           |
# | n_updates          | 64            |
# | policy_entropy     | 0.034478858   |
# | policy_loss        | -0.0022016282 |
# | serial_timesteps   | 8192          |
# | time_elapsed       | 15.7          |
# | total_timesteps    | 8192          |
# | value_loss         | 0.0038700055  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.7856636e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.27         |
# | fps                | 515           |
# | n_updates          | 65            |
# | policy_entropy     | 0.04039683    |
# | policy_loss        | -0.0029472448 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 16            |
# | total_timesteps    | 8320          |
# | value_loss         | 0.0061602592  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.71444e-07    |
# | clipfrac           | 0.0            |
# | explained_variance | -4.51          |
# | fps                | 511            |
# | n_updates          | 66             |
# | policy_entropy     | 0.031264424    |
# | policy_loss        | -0.00020335708 |
# | serial_timesteps   | 8448           |
# | time_elapsed       | 16.2           |
# | total_timesteps    | 8448           |
# | value_loss         | 0.0031940797   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00024352792 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -12.1         |
# | fps                | 514           |
# | n_updates          | 67            |
# | policy_entropy     | 0.03202169    |
# | policy_loss        | -0.004417696  |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 16.5          |
# | total_timesteps    | 8576          |
# | value_loss         | 0.0022965276  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.1687025e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.059         |
# | fps                | 467           |
# | n_updates          | 68            |
# | policy_entropy     | 0.029475607   |
# | policy_loss        | 1.5792146e-05 |
# | serial_timesteps   | 8704          |
# | time_elapsed       | 16.7          |
# | total_timesteps    | 8704          |
# | value_loss         | 1.052804      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.7934814e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0393         |
# | fps                | 478            |
# | n_updates          | 69             |
# | policy_entropy     | 0.033395432    |
# | policy_loss        | -0.00018652214 |
# | serial_timesteps   | 8832           |
# | time_elapsed       | 17             |
# | total_timesteps    | 8832           |
# | value_loss         | 0.07065979     |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.20719005e-05 |
# | clipfrac           | 0.0            |
# | explained_variance | -2.45          |
# | fps                | 460            |
# | n_updates          | 70             |
# | policy_entropy     | 0.024649456    |
# | policy_loss        | -0.00034683442 |
# | serial_timesteps   | 8960           |
# | time_elapsed       | 17.3           |
# | total_timesteps    | 8960           |
# | value_loss         | 0.0021704575   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00012957808 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -1.57         |
# | fps                | 495           |
# | n_updates          | 71            |
# | policy_entropy     | 0.032111995   |
# | policy_loss        | -0.0029997393 |
# | serial_timesteps   | 9088          |
# | time_elapsed       | 17.5          |
# | total_timesteps    | 9088          |
# | value_loss         | 0.0028978852  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004783358  |
# | clipfrac           | 0.005859375   |
# | explained_variance | -4.22         |
# | fps                | 493           |
# | n_updates          | 72            |
# | policy_entropy     | 0.025576413   |
# | policy_loss        | -0.0049151797 |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 17.8          |
# | total_timesteps    | 9216          |
# | value_loss         | 0.005879204   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.023285e-07   |
# | clipfrac           | 0.0            |
# | explained_variance | -1.37          |
# | fps                | 515            |
# | n_updates          | 73             |
# | policy_entropy     | 0.025433313    |
# | policy_loss        | -3.4907716e-05 |
# | serial_timesteps   | 9344           |
# | time_elapsed       | 18.1           |
# | total_timesteps    | 9344           |
# | value_loss         | 0.003678842    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 7.5304583e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0416        |
# | fps                | 515            |
# | n_updates          | 74             |
# | policy_entropy     | 0.034351792    |
# | policy_loss        | -0.00032331748 |
# | serial_timesteps   | 9472           |
# | time_elapsed       | 18.3           |
# | total_timesteps    | 9472           |
# | value_loss         | 4.493634       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.073894e-07  |
# | clipfrac           | 0.0           |
# | explained_variance | -3.8          |
# | fps                | 511           |
# | n_updates          | 75            |
# | policy_entropy     | 0.020147275   |
# | policy_loss        | -0.0002537201 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 18.6          |
# | total_timesteps    | 9600          |
# | value_loss         | 0.0036189116  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00041446424 |
# | clipfrac           | 0.0078125     |
# | explained_variance | -4.68         |
# | fps                | 497           |
# | n_updates          | 76            |
# | policy_entropy     | 0.029360488   |
# | policy_loss        | -0.007292578  |
# | serial_timesteps   | 9728          |
# | time_elapsed       | 18.8          |
# | total_timesteps    | 9728          |
# | value_loss         | 0.0042488165  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.8733193e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -6.8          |
# | fps                | 539           |
# | n_updates          | 77            |
# | policy_entropy     | 0.02167118    |
# | policy_loss        | -0.0007381127 |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 19.1          |
# | total_timesteps    | 9856          |
# | value_loss         | 0.0029758557  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.1728835e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.22         |
# | fps                | 465           |
# | n_updates          | 78            |
# | policy_entropy     | 0.029431801   |
# | policy_loss        | -0.0012099488 |
# | serial_timesteps   | 9984          |
# | time_elapsed       | 19.3          |
# | total_timesteps    | 9984          |
# | value_loss         | 0.0038944066  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.4588706e-07  |
# | clipfrac           | 0.0            |
# | explained_variance | -11.1          |
# | fps                | 496            |
# | n_updates          | 79             |
# | policy_entropy     | 0.01740979     |
# | policy_loss        | -0.00039318996 |
# | serial_timesteps   | 10112          |
# | time_elapsed       | 19.6           |
# | total_timesteps    | 10112          |
# | value_loss         | 0.0014192641   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.1711544e-05 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -17.6         |
# | fps                | 540           |
# | n_updates          | 80            |
# | policy_entropy     | 0.018590448   |
# | policy_loss        | -0.003821136  |
# | serial_timesteps   | 10240         |
# | time_elapsed       | 19.8          |
# | total_timesteps    | 10240         |
# | value_loss         | 0.0022196972  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.8227307e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -6.59         |
# | fps                | 507           |
# | n_updates          | 81            |
# | policy_entropy     | 0.01867941    |
# | policy_loss        | -0.0013933574 |
# | serial_timesteps   | 10368         |
# | time_elapsed       | 20.1          |
# | total_timesteps    | 10368         |
# | value_loss         | 0.0018670871  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00033821046 |
# | clipfrac           | 0.0078125     |
# | explained_variance | -6.9          |
# | fps                | 529           |
# | n_updates          | 82            |
# | policy_entropy     | 0.028215019   |
# | policy_loss        | -0.005379842  |
# | serial_timesteps   | 10496         |
# | time_elapsed       | 20.3          |
# | total_timesteps    | 10496         |
# | value_loss         | 0.0019019413  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0001504139  |
# | clipfrac           | 0.00390625    |
# | explained_variance | -19.6         |
# | fps                | 525           |
# | n_updates          | 83            |
# | policy_entropy     | 0.021543037   |
# | policy_loss        | -0.0019727852 |
# | serial_timesteps   | 10624         |
# | time_elapsed       | 20.6          |
# | total_timesteps    | 10624         |
# | value_loss         | 0.0036953539  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.5955055e-08  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.