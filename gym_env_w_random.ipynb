# %%
from load_data import load_data
from add_reward import add_reward_df

# %%
df = load_data()
df = add_reward_df(df)

# %%
df = df.reset_index()

# %%
min_values = df.describe().loc['min']
max_values = df.describe().loc['max']

# %%
min_observation= min_values.loc[~min_values.index.isin(['SepsisLabel',
                                                        'patient', 
                                                        'zeros_reward',
                                                        'ones_reward'])].min()

max_observation = max_values.loc[~max_values.index.isin(['SepsisLabel',
                                                         'patient',
                                                         'zeros_reward',
                                                         'ones_reward'])].max()

# %%
min_observation
# Out:
# -25.545204389483803

# %%
max_observation
# Out:
# 335.0

# %%
import random
import json
import gym
from gym import spaces
import pandas as pd
import numpy as np


class SepsisEnv(gym.Env):
    """A Sepsis environment for OpenAI gym"""
    metadata = {'render.modes': ['human']}
    
    def __init__(self, df):
        super(SepsisEnv, self).__init__()

        self.df = df
        self.reward_range = (-2.0, 1.0)
        # Only two possible actions, 0 for non-sepsis,
        # 1 for sepsis.
        n_actions = 2
        self.action_space = spaces.Discrete(n=n_actions)
        # Observation space is a feature vector of 41 vital signs, 
        # lab values, and other demographic information.
        self.observation_space = spaces.Box(
            low=-25.545204389483803, high=335.0, shape=(1, 42), dtype=np.float16)

    def _next_observation(self):
        obs = np.array([
        self.df.loc[self.current_step, ~df.columns.isin(['SepsisLabel',
                            'patient', 
                            'zeros_reward',
                            'ones_reward'])].values 

        ])

        return obs


    def step(self, action):
        # Execute one time step within the environment
        self.current_step += 1
        
        if action == 0:
            reward = self.df.loc[self.current_step, ['zeros_reward']]
        else:
            reward = self.df.loc[self.current_step, ['ones_reward']]

        done = False

        obs = self._next_observation()

        return obs, reward, done, {}

    def reset(self):
        # Reset the state of the environment to an initial state
        # Set the current step to a random point within the data frame
#         self.current_step = random.randint(
#             0, len(self.df.loc[:, 'HR'].values))
        self.current_step = 0

        return self._next_observation()

    def render(self, mode='human', close=False):
        # Render the environment to the screen
        print('current step' ,self.current_step)

# %%
import gym
import json
import datetime as dt
from stable_baselines.common.policies import MlpPolicy
from stable_baselines.common.vec_env import DummyVecEnv
from stable_baselines import PPO2
import pandas as pd
# Out:
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /data/zsbarnes/anaconda3/envs/rl_sepsis/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Muli-layer Perception Model

# %%
env = DummyVecEnv([lambda: SepsisEnv(df)])
model = PPO2(MlpPolicy, env, verbose=1)
model.learn(total_timesteps=20000)
reward_list = []
for i in range(500): 
    obs = env.reset()
    action, _states = model.predict(obs)
    obs, rewards, done, info = env.step(action)
    reward_list.append(rewards)
# Out:
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f1cb0430e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f1cb0430e90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f1cb0430e90>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f1cb0430e90>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING:tensorflow:Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f1cb02e2e50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f1cb02e2e50>>: AttributeError: module 'gast' has no attribute 'Num'
# WARNING: Entity <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f1cb02e2e50>> could not be transformed and will be executed as-is. Please report this to the AutgoGraph team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output. Cause: converting <bound method Flatten.call of <tensorflow.python.layers.core.Flatten object at 0x7f1cb02e2e50>>: AttributeError: module 'gast' has no attribute 'Num'
# --------------------------------------
# | approxkl           | 0.0030465946  |
# | clipfrac           | 0.0           |
# | explained_variance | -6.22         |
# | fps                | 247           |
# | n_updates          | 1             |
# | policy_entropy     | 0.6905858     |
# | policy_loss        | -0.0132151125 |
# | serial_timesteps   | 128           |
# | time_elapsed       | 1.17e-05      |
# | total_timesteps    | 128           |
# | value_loss         | 0.0394027     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0020915268  |
# | clipfrac           | 0.0           |
# | explained_variance | -4.47         |
# | fps                | 526           |
# | n_updates          | 2             |
# | policy_entropy     | 0.6740954     |
# | policy_loss        | -0.0040575666 |
# | serial_timesteps   | 256           |
# | time_elapsed       | 0.518         |
# | total_timesteps    | 256           |
# | value_loss         | 0.04418189    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0016695806  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.852        |
# | fps                | 547           |
# | n_updates          | 3             |
# | policy_entropy     | 0.6468173     |
# | policy_loss        | -0.0063350163 |
# | serial_timesteps   | 384           |
# | time_elapsed       | 0.762         |
# | total_timesteps    | 384           |
# | value_loss         | 0.0076759886  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00068927143 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0191       |
# | fps                | 515           |
# | n_updates          | 4             |
# | policy_entropy     | 0.612204      |
# | policy_loss        | 0.0018607338  |
# | serial_timesteps   | 512           |
# | time_elapsed       | 0.996         |
# | total_timesteps    | 512           |
# | value_loss         | 0.5169698     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.9196757e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0412        |
# | fps                | 506           |
# | n_updates          | 5             |
# | policy_entropy     | 0.6278611     |
# | policy_loss        | 0.00018863409 |
# | serial_timesteps   | 640           |
# | time_elapsed       | 1.25          |
# | total_timesteps    | 640           |
# | value_loss         | 1.3120099     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0005679172  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.52         |
# | fps                | 473           |
# | n_updates          | 6             |
# | policy_entropy     | 0.6188736     |
# | policy_loss        | -0.0034199366 |
# | serial_timesteps   | 768           |
# | time_elapsed       | 1.5           |
# | total_timesteps    | 768           |
# | value_loss         | 0.017480383   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018352951 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.246        |
# | fps                | 458           |
# | n_updates          | 7             |
# | policy_entropy     | 0.5896945     |
# | policy_loss        | -0.0006095551 |
# | serial_timesteps   | 896           |
# | time_elapsed       | 1.77          |
# | total_timesteps    | 896           |
# | value_loss         | 0.1719138     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.0798946e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0243        |
# | fps                | 488            |
# | n_updates          | 8              |
# | policy_entropy     | 0.5899542      |
# | policy_loss        | -0.00014709798 |
# | serial_timesteps   | 1024           |
# | time_elapsed       | 2.05           |
# | total_timesteps    | 1024           |
# | value_loss         | 0.9085057      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.8240154e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0155        |
# | fps                | 468           |
# | n_updates          | 9             |
# | policy_entropy     | 0.60053974    |
# | policy_loss        | -0.001115401  |
# | serial_timesteps   | 1152          |
# | time_elapsed       | 2.31          |
# | total_timesteps    | 1152          |
# | value_loss         | 1.8079075     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00013594219 |
# | clipfrac           | 0.0           |
# | explained_variance | -2.48         |
# | fps                | 507           |
# | n_updates          | 10            |
# | policy_entropy     | 0.59155655    |
# | policy_loss        | -0.0013145654 |
# | serial_timesteps   | 1280          |
# | time_elapsed       | 2.59          |
# | total_timesteps    | 1280          |
# | value_loss         | 0.018147755   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00042205048 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0876       |
# | fps                | 487           |
# | n_updates          | 11            |
# | policy_entropy     | 0.57841295    |
# | policy_loss        | 0.0015380597  |
# | serial_timesteps   | 1408          |
# | time_elapsed       | 2.84          |
# | total_timesteps    | 1408          |
# | value_loss         | 0.8278845     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.073627e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0335       |
# | fps                | 518           |
# | n_updates          | 12            |
# | policy_entropy     | 0.5696478     |
# | policy_loss        | -8.577423e-05 |
# | serial_timesteps   | 1536          |
# | time_elapsed       | 3.1           |
# | total_timesteps    | 1536          |
# | value_loss         | 1.0983664     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00043959834 |
# | clipfrac           | 0.0           |
# | explained_variance | -4.15         |
# | fps                | 557           |
# | n_updates          | 13            |
# | policy_entropy     | 0.5614163     |
# | policy_loss        | -0.0033579103 |
# | serial_timesteps   | 1664          |
# | time_elapsed       | 3.35          |
# | total_timesteps    | 1664          |
# | value_loss         | 0.024419582   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0015226941  |
# | clipfrac           | 0.0           |
# | explained_variance | -7.64         |
# | fps                | 522           |
# | n_updates          | 14            |
# | policy_entropy     | 0.526848      |
# | policy_loss        | -0.0043677427 |
# | serial_timesteps   | 1792          |
# | time_elapsed       | 3.58          |
# | total_timesteps    | 1792          |
# | value_loss         | 0.024510322   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023695099 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0598        |
# | fps                | 491           |
# | n_updates          | 15            |
# | policy_entropy     | 0.49055883    |
# | policy_loss        | 0.0012263645  |
# | serial_timesteps   | 1920          |
# | time_elapsed       | 3.83          |
# | total_timesteps    | 1920          |
# | value_loss         | 3.303101      |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 7.939383e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0222        |
# | fps                | 554            |
# | n_updates          | 16             |
# | policy_entropy     | 0.4908193      |
# | policy_loss        | -6.2864216e-05 |
# | serial_timesteps   | 2048           |
# | time_elapsed       | 4.09           |
# | total_timesteps    | 2048           |
# | value_loss         | 1.1955117      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0003192861  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0657       |
# | fps                | 532           |
# | n_updates          | 17            |
# | policy_entropy     | 0.5131825     |
# | policy_loss        | -0.0015958678 |
# | serial_timesteps   | 2176          |
# | time_elapsed       | 4.32          |
# | total_timesteps    | 2176          |
# | value_loss         | 0.37097588    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000114616945 |
# | clipfrac           | 0.0            |
# | explained_variance | -9.93          |
# | fps                | 490            |
# | n_updates          | 18             |
# | policy_entropy     | 0.51543856     |
# | policy_loss        | -0.0032933513  |
# | serial_timesteps   | 2304           |
# | time_elapsed       | 4.56           |
# | total_timesteps    | 2304           |
# | value_loss         | 0.01485732     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0005472827  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0235       |
# | fps                | 530           |
# | n_updates          | 19            |
# | policy_entropy     | 0.47645274    |
# | policy_loss        | -0.0004633722 |
# | serial_timesteps   | 2432          |
# | time_elapsed       | 4.82          |
# | total_timesteps    | 2432          |
# | value_loss         | 0.35508657    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 8.805495e-05   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0245        |
# | fps                | 475            |
# | n_updates          | 20             |
# | policy_entropy     | 0.47675115     |
# | policy_loss        | -0.00057136465 |
# | serial_timesteps   | 2560           |
# | time_elapsed       | 5.07           |
# | total_timesteps    | 2560           |
# | value_loss         | 0.15612178     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.001200057   |
# | clipfrac           | 0.0           |
# | explained_variance | -2.84         |
# | fps                | 505           |
# | n_updates          | 21            |
# | policy_entropy     | 0.44265392    |
# | policy_loss        | -0.0037680622 |
# | serial_timesteps   | 2688          |
# | time_elapsed       | 5.34          |
# | total_timesteps    | 2688          |
# | value_loss         | 0.018136773   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0009360951  |
# | clipfrac           | 0.0           |
# | explained_variance | -9.76         |
# | fps                | 525           |
# | n_updates          | 22            |
# | policy_entropy     | 0.38992047    |
# | policy_loss        | -0.0021912232 |
# | serial_timesteps   | 2816          |
# | time_elapsed       | 5.59          |
# | total_timesteps    | 2816          |
# | value_loss         | 0.016750189   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0004919281  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.47         |
# | fps                | 469           |
# | n_updates          | 23            |
# | policy_entropy     | 0.35712078    |
# | policy_loss        | -0.0015970739 |
# | serial_timesteps   | 2944          |
# | time_elapsed       | 5.83          |
# | total_timesteps    | 2944          |
# | value_loss         | 0.014941121   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.6851858e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.11         |
# | fps                | 501           |
# | n_updates          | 24            |
# | policy_entropy     | 0.32932648    |
# | policy_loss        | -0.0005506377 |
# | serial_timesteps   | 3072          |
# | time_elapsed       | 6.11          |
# | total_timesteps    | 3072          |
# | value_loss         | 0.012868621   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018572007 |
# | clipfrac           | 0.0           |
# | explained_variance | -6.78         |
# | fps                | 489           |
# | n_updates          | 25            |
# | policy_entropy     | 0.35434377    |
# | policy_loss        | -0.0018629824 |
# | serial_timesteps   | 3200          |
# | time_elapsed       | 6.36          |
# | total_timesteps    | 3200          |
# | value_loss         | 0.0141180605  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.233488e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -4.24         |
# | fps                | 516           |
# | n_updates          | 26            |
# | policy_entropy     | 0.36122203    |
# | policy_loss        | -0.0023291502 |
# | serial_timesteps   | 3328          |
# | time_elapsed       | 6.63          |
# | total_timesteps    | 3328          |
# | value_loss         | 0.0066052955  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0020002485 |
# | clipfrac           | 0.029296875  |
# | explained_variance | -4.16        |
# | fps                | 518          |
# | n_updates          | 27           |
# | policy_entropy     | 0.32240912   |
# | policy_loss        | -0.011752151 |
# | serial_timesteps   | 3456         |
# | time_elapsed       | 6.88         |
# | total_timesteps    | 3456         |
# | value_loss         | 0.008243782  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0021005892 |
# | clipfrac           | 0.02734375   |
# | explained_variance | -7.01        |
# | fps                | 546          |
# | n_updates          | 28           |
# | policy_entropy     | 0.31895733   |
# | policy_loss        | -0.013626929 |
# | serial_timesteps   | 3584         |
# | time_elapsed       | 7.12         |
# | total_timesteps    | 3584         |
# | value_loss         | 0.014556258  |
# -------------------------------------
# --------------------------------------
# | approxkl           | 0.0013192919  |
# | clipfrac           | 0.017578125   |
# | explained_variance | -3.33         |
# | fps                | 475           |
# | n_updates          | 29            |
# | policy_entropy     | 0.22328924    |
# | policy_loss        | -0.0075459923 |
# | serial_timesteps   | 3712          |
# | time_elapsed       | 7.36          |
# | total_timesteps    | 3712          |
# | value_loss         | 0.008986904   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011603221 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.32         |
# | fps                | 511           |
# | n_updates          | 30            |
# | policy_entropy     | 0.1940901     |
# | policy_loss        | -0.0016499942 |
# | serial_timesteps   | 3840          |
# | time_elapsed       | 7.63          |
# | total_timesteps    | 3840          |
# | value_loss         | 0.007511927   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.724536e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -3.75         |
# | fps                | 519           |
# | n_updates          | 31            |
# | policy_entropy     | 0.17336532    |
# | policy_loss        | -0.0017316388 |
# | serial_timesteps   | 3968          |
# | time_elapsed       | 7.88          |
# | total_timesteps    | 3968          |
# | value_loss         | 0.006179292   |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0003427327 |
# | clipfrac           | 0.001953125  |
# | explained_variance | -2.08        |
# | fps                | 543          |
# | n_updates          | 32           |
# | policy_entropy     | 0.1558189    |
# | policy_loss        | -0.005548742 |
# | serial_timesteps   | 4096         |
# | time_elapsed       | 8.13         |
# | total_timesteps    | 4096         |
# | value_loss         | 0.009351094  |
# -------------------------------------
# -------------------------------------
# | approxkl           | 0.0008940709 |
# | clipfrac           | 0.015625     |
# | explained_variance | -17.2        |
# | fps                | 534          |
# | n_updates          | 33           |
# | policy_entropy     | 0.13708791   |
# | policy_loss        | -0.006547277 |
# | serial_timesteps   | 4224         |
# | time_elapsed       | 8.36         |
# | total_timesteps    | 4224         |
# | value_loss         | 0.0065119225 |
# -------------------------------------
# --------------------------------------
# | approxkl           | 7.1456205e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0251        |
# | fps                | 504           |
# | n_updates          | 34            |
# | policy_entropy     | 0.11235158    |
# | policy_loss        | -0.0010144433 |
# | serial_timesteps   | 4352          |
# | time_elapsed       | 8.6           |
# | total_timesteps    | 4352          |
# | value_loss         | 1.8475695     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00046763197 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -17.9         |
# | fps                | 523           |
# | n_updates          | 35            |
# | policy_entropy     | 0.09883511    |
# | policy_loss        | -0.0068567786 |
# | serial_timesteps   | 4480          |
# | time_elapsed       | 8.86          |
# | total_timesteps    | 4480          |
# | value_loss         | 0.007101157   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.4065495e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -11.9         |
# | fps                | 552           |
# | n_updates          | 36            |
# | policy_entropy     | 0.08877939    |
# | policy_loss        | 0.00026674278 |
# | serial_timesteps   | 4608          |
# | time_elapsed       | 9.1           |
# | total_timesteps    | 4608          |
# | value_loss         | 0.005814587   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00011047612 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -2.86         |
# | fps                | 493           |
# | n_updates          | 37            |
# | policy_entropy     | 0.10817195    |
# | policy_loss        | -0.003383388  |
# | serial_timesteps   | 4736          |
# | time_elapsed       | 9.34          |
# | total_timesteps    | 4736          |
# | value_loss         | 0.008095836   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.717309e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -5.36         |
# | fps                | 487           |
# | n_updates          | 38            |
# | policy_entropy     | 0.102606975   |
# | policy_loss        | -0.0027137452 |
# | serial_timesteps   | 4864          |
# | time_elapsed       | 9.6           |
# | total_timesteps    | 4864          |
# | value_loss         | 0.006683376   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.6978709e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0112        |
# | fps                | 512           |
# | n_updates          | 39            |
# | policy_entropy     | 0.097493716   |
# | policy_loss        | -6.356486e-05 |
# | serial_timesteps   | 4992          |
# | time_elapsed       | 9.86          |
# | total_timesteps    | 4992          |
# | value_loss         | 2.4273114     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00036094076 |
# | clipfrac           | 0.005859375   |
# | explained_variance | -17.3         |
# | fps                | 498           |
# | n_updates          | 40            |
# | policy_entropy     | 0.09660334    |
# | policy_loss        | -0.006441136  |
# | serial_timesteps   | 5120          |
# | time_elapsed       | 10.1          |
# | total_timesteps    | 5120          |
# | value_loss         | 0.00607756    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.9706877e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00582      |
# | fps                | 494           |
# | n_updates          | 41            |
# | policy_entropy     | 0.0908192     |
# | policy_loss        | 1.0360964e-05 |
# | serial_timesteps   | 5248          |
# | time_elapsed       | 10.4          |
# | total_timesteps    | 5248          |
# | value_loss         | 2.7022018     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00018396937 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -3.13         |
# | fps                | 469           |
# | n_updates          | 42            |
# | policy_entropy     | 0.07861533    |
# | policy_loss        | -0.0019232009 |
# | serial_timesteps   | 5376          |
# | time_elapsed       | 10.6          |
# | total_timesteps    | 5376          |
# | value_loss         | 0.0059568714  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.0559587e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0173        |
# | fps                | 471            |
# | n_updates          | 43             |
# | policy_entropy     | 0.07761503     |
# | policy_loss        | -0.00021676696 |
# | serial_timesteps   | 5504           |
# | time_elapsed       | 10.9           |
# | total_timesteps    | 5504           |
# | value_loss         | 2.6879826      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.8051833e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -9.26         |
# | fps                | 499           |
# | n_updates          | 44            |
# | policy_entropy     | 0.08975617    |
# | policy_loss        | -0.001225169  |
# | serial_timesteps   | 5632          |
# | time_elapsed       | 11.2          |
# | total_timesteps    | 5632          |
# | value_loss         | 0.0036820683  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.0072176e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -5.12          |
# | fps                | 510            |
# | n_updates          | 45             |
# | policy_entropy     | 0.076927274    |
# | policy_loss        | -0.00014907832 |
# | serial_timesteps   | 5760           |
# | time_elapsed       | 11.4           |
# | total_timesteps    | 5760           |
# | value_loss         | 0.0036302344   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.0421611e-08  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0163         |
# | fps                | 494            |
# | n_updates          | 46             |
# | policy_entropy     | 0.070375755    |
# | policy_loss        | -1.6594306e-05 |
# | serial_timesteps   | 5888           |
# | time_elapsed       | 11.7           |
# | total_timesteps    | 5888           |
# | value_loss         | 1.6858227      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00030420933 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -4.95         |
# | fps                | 496           |
# | n_updates          | 47            |
# | policy_entropy     | 0.11350883    |
# | policy_loss        | -0.004335874  |
# | serial_timesteps   | 6016          |
# | time_elapsed       | 11.9          |
# | total_timesteps    | 6016          |
# | value_loss         | 0.0072506345  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.8099217e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.572         |
# | fps                | 528            |
# | n_updates          | 48             |
# | policy_entropy     | 0.08506122     |
# | policy_loss        | -0.00066616037 |
# | serial_timesteps   | 6144           |
# | time_elapsed       | 12.2           |
# | total_timesteps    | 6144           |
# | value_loss         | 0.003046819    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 7.191309e-07   |
# | clipfrac           | 0.0            |
# | explained_variance | -2.88          |
# | fps                | 567            |
# | n_updates          | 49             |
# | policy_entropy     | 0.068581976    |
# | policy_loss        | -0.00018969818 |
# | serial_timesteps   | 6272           |
# | time_elapsed       | 12.4           |
# | total_timesteps    | 6272           |
# | value_loss         | 0.0017128773   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.3168214e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0192       |
# | fps                | 552           |
# | n_updates          | 50            |
# | policy_entropy     | 0.08918113    |
# | policy_loss        | -7.142802e-05 |
# | serial_timesteps   | 6400          |
# | time_elapsed       | 12.7          |
# | total_timesteps    | 6400          |
# | value_loss         | 5.3110857     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.213995e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0287       |
# | fps                | 481           |
# | n_updates          | 51            |
# | policy_entropy     | 0.096477285   |
# | policy_loss        | -0.0006602948 |
# | serial_timesteps   | 6528          |
# | time_elapsed       | 12.9          |
# | total_timesteps    | 6528          |
# | value_loss         | 1.0687175     |
# --------------------------------------
# -------------------------------------
# | approxkl           | 0.0009313489 |
# | clipfrac           | 0.009765625  |
# | explained_variance | -9.73        |
# | fps                | 505          |
# | n_updates          | 52           |
# | policy_entropy     | 0.080155805  |
# | policy_loss        | -0.011240607 |
# | serial_timesteps   | 6656         |
# | time_elapsed       | 13.2         |
# | total_timesteps    | 6656         |
# | value_loss         | 0.008350634  |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 4.6332047e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -2.45          |
# | fps                | 532            |
# | n_updates          | 53             |
# | policy_entropy     | 0.07549408     |
# | policy_loss        | -0.00064384646 |
# | serial_timesteps   | 6784           |
# | time_elapsed       | 13.4           |
# | total_timesteps    | 6784           |
# | value_loss         | 0.003693136    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00017758363 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -0.962        |
# | fps                | 515           |
# | n_updates          | 54            |
# | policy_entropy     | 0.065138415   |
# | policy_loss        | -0.0034981575 |
# | serial_timesteps   | 6912          |
# | time_elapsed       | 13.7          |
# | total_timesteps    | 6912          |
# | value_loss         | 0.0045170803  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 7.9870384e-05 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -0.0209       |
# | fps                | 453           |
# | n_updates          | 55            |
# | policy_entropy     | 0.07564719    |
# | policy_loss        | -0.0013370683 |
# | serial_timesteps   | 7040          |
# | time_elapsed       | 13.9          |
# | total_timesteps    | 7040          |
# | value_loss         | 1.7062975     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00023070059 |
# | clipfrac           | 0.005859375   |
# | explained_variance | -6.16         |
# | fps                | 458           |
# | n_updates          | 56            |
# | policy_entropy     | 0.08226912    |
# | policy_loss        | -0.004631213  |
# | serial_timesteps   | 7168          |
# | time_elapsed       | 14.2          |
# | total_timesteps    | 7168          |
# | value_loss         | 0.0049779387  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 0.000113520764 |
# | clipfrac           | 0.001953125    |
# | explained_variance | -2.94          |
# | fps                | 529            |
# | n_updates          | 57             |
# | policy_entropy     | 0.103617415    |
# | policy_loss        | -0.003841036   |
# | serial_timesteps   | 7296           |
# | time_elapsed       | 14.5           |
# | total_timesteps    | 7296           |
# | value_loss         | 0.0034204952   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00016951533 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -5.28         |
# | fps                | 492           |
# | n_updates          | 58            |
# | policy_entropy     | 0.09635001    |
# | policy_loss        | -0.0040931418 |
# | serial_timesteps   | 7424          |
# | time_elapsed       | 14.7          |
# | total_timesteps    | 7424          |
# | value_loss         | 0.0036104897  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 8.3845625e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -6.33         |
# | fps                | 531           |
# | n_updates          | 59            |
# | policy_entropy     | 0.08740334    |
# | policy_loss        | -0.0025054838 |
# | serial_timesteps   | 7552          |
# | time_elapsed       | 15            |
# | total_timesteps    | 7552          |
# | value_loss         | 0.0023041295  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.242231e-05  |
# | clipfrac           | 0.0           |
# | explained_variance | -20.9         |
# | fps                | 482           |
# | n_updates          | 60            |
# | policy_entropy     | 0.07320738    |
# | policy_loss        | -0.0010835592 |
# | serial_timesteps   | 7680          |
# | time_elapsed       | 15.2          |
# | total_timesteps    | 7680          |
# | value_loss         | 0.0027473802  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.52056e-05   |
# | clipfrac           | 0.0           |
# | explained_variance | -27.5         |
# | fps                | 485           |
# | n_updates          | 61            |
# | policy_entropy     | 0.07637803    |
# | policy_loss        | -0.0021454883 |
# | serial_timesteps   | 7808          |
# | time_elapsed       | 15.5          |
# | total_timesteps    | 7808          |
# | value_loss         | 0.003989305   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.2309345e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.763         |
# | fps                | 497            |
# | n_updates          | 62             |
# | policy_entropy     | 0.064524285    |
# | policy_loss        | -0.00043840264 |
# | serial_timesteps   | 7936           |
# | time_elapsed       | 15.8           |
# | total_timesteps    | 7936           |
# | value_loss         | 0.001533593    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.6040022e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -17.3         |
# | fps                | 561           |
# | n_updates          | 63            |
# | policy_entropy     | 0.06869116    |
# | policy_loss        | -0.0013431138 |
# | serial_timesteps   | 8064          |
# | time_elapsed       | 16            |
# | total_timesteps    | 8064          |
# | value_loss         | 0.0023100881  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.5925209e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -9.02          |
# | fps                | 516            |
# | n_updates          | 64             |
# | policy_entropy     | 0.055660013    |
# | policy_loss        | -0.00044491654 |
# | serial_timesteps   | 8192           |
# | time_elapsed       | 16.2           |
# | total_timesteps    | 8192           |
# | value_loss         | 0.0013514326   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.9558514e-05 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -11.3         |
# | fps                | 520           |
# | n_updates          | 65            |
# | policy_entropy     | 0.055474237   |
# | policy_loss        | -0.0044465815 |
# | serial_timesteps   | 8320          |
# | time_elapsed       | 16.5          |
# | total_timesteps    | 8320          |
# | value_loss         | 0.0035133262  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.1753307e-07  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0162         |
# | fps                | 520            |
# | n_updates          | 66             |
# | policy_entropy     | 0.05344635     |
# | policy_loss        | -5.7102006e-05 |
# | serial_timesteps   | 8448           |
# | time_elapsed       | 16.7           |
# | total_timesteps    | 8448           |
# | value_loss         | 2.6761994      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.479633e-05  |
# | clipfrac           | 0.001953125   |
# | explained_variance | -8.77         |
# | fps                | 523           |
# | n_updates          | 67            |
# | policy_entropy     | 0.05062103    |
# | policy_loss        | -0.0009720846 |
# | serial_timesteps   | 8576          |
# | time_elapsed       | 17            |
# | total_timesteps    | 8576          |
# | value_loss         | 0.005225471   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.019255e-08  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00297       |
# | fps                | 518           |
# | n_updates          | 68            |
# | policy_entropy     | 0.050040323   |
# | policy_loss        | -2.400449e-05 |
# | serial_timesteps   | 8704          |
# | time_elapsed       | 17.2          |
# | total_timesteps    | 8704          |
# | value_loss         | 1.7092474     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.6393745e-08 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0223        |
# | fps                | 481           |
# | n_updates          | 69            |
# | policy_entropy     | 0.048116095   |
# | policy_loss        | -7.611001e-06 |
# | serial_timesteps   | 8832          |
# | time_elapsed       | 17.5          |
# | total_timesteps    | 8832          |
# | value_loss         | 2.6695025     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.0002000015  |
# | clipfrac           | 0.00390625    |
# | explained_variance | -6.55         |
# | fps                | 460           |
# | n_updates          | 70            |
# | policy_entropy     | 0.048177112   |
# | policy_loss        | -0.0036239221 |
# | serial_timesteps   | 8960          |
# | time_elapsed       | 17.7          |
# | total_timesteps    | 8960          |
# | value_loss         | 0.0078324815  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.619188e-07   |
# | clipfrac           | 0.0            |
# | explained_variance | -4.76          |
# | fps                | 486            |
# | n_updates          | 71             |
# | policy_entropy     | 0.05034295     |
# | policy_loss        | -0.00018454937 |
# | serial_timesteps   | 9088           |
# | time_elapsed       | 18             |
# | total_timesteps    | 9088           |
# | value_loss         | 0.0044994843   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.1596926e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -4.28         |
# | fps                | 487           |
# | n_updates          | 72            |
# | policy_entropy     | 0.04997999    |
# | policy_loss        | -0.0026142069 |
# | serial_timesteps   | 9216          |
# | time_elapsed       | 18.3          |
# | total_timesteps    | 9216          |
# | value_loss         | 0.0035367974  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 2.2877995e-07 |
# | clipfrac           | 0.0           |
# | explained_variance | -8.39         |
# | fps                | 509           |
# | n_updates          | 73            |
# | policy_entropy     | 0.054390945   |
# | policy_loss        | 0.00011533033 |
# | serial_timesteps   | 9344          |
# | time_elapsed       | 18.6          |
# | total_timesteps    | 9344          |
# | value_loss         | 0.0032722573  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.1124446e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -6.79          |
# | fps                | 502            |
# | n_updates          | 74             |
# | policy_entropy     | 0.050752115    |
# | policy_loss        | -0.00086300704 |
# | serial_timesteps   | 9472           |
# | time_elapsed       | 18.8           |
# | total_timesteps    | 9472           |
# | value_loss         | 0.00292131     |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 9.538371e-07  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.724        |
# | fps                | 448           |
# | n_updates          | 75            |
# | policy_entropy     | 0.045060355   |
# | policy_loss        | -0.0005083523 |
# | serial_timesteps   | 9600          |
# | time_elapsed       | 19.1          |
# | total_timesteps    | 9600          |
# | value_loss         | 0.0010808983  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.4946931e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0216         |
# | fps                | 509            |
# | n_updates          | 76             |
# | policy_entropy     | 0.057608005    |
# | policy_loss        | -0.00032038696 |
# | serial_timesteps   | 9728           |
# | time_elapsed       | 19.3           |
# | total_timesteps    | 9728           |
# | value_loss         | 2.6177762      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00010723759 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -10.3         |
# | fps                | 515           |
# | n_updates          | 77            |
# | policy_entropy     | 0.043371595   |
# | policy_loss        | -0.0014540106 |
# | serial_timesteps   | 9856          |
# | time_elapsed       | 19.6          |
# | total_timesteps    | 9856          |
# | value_loss         | 0.004012842   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.0335636e-07  |
# | clipfrac           | 0.0            |
# | explained_variance | -2.83          |
# | fps                | 517            |
# | n_updates          | 78             |
# | policy_entropy     | 0.03715688     |
# | policy_loss        | -0.00014079071 |
# | serial_timesteps   | 9984           |
# | time_elapsed       | 19.8           |
# | total_timesteps    | 9984           |
# | value_loss         | 0.0028560222   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.5544352e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00228       |
# | fps                | 495           |
# | n_updates          | 79            |
# | policy_entropy     | 0.03474644    |
# | policy_loss        | -0.0008797186 |
# | serial_timesteps   | 10112         |
# | time_elapsed       | 20.1          |
# | total_timesteps    | 10112         |
# | value_loss         | 2.4662406     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.4741491e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.33         |
# | fps                | 534           |
# | n_updates          | 80            |
# | policy_entropy     | 0.042867362   |
# | policy_loss        | -0.0004048245 |
# | serial_timesteps   | 10240         |
# | time_elapsed       | 20.4          |
# | total_timesteps    | 10240         |
# | value_loss         | 0.0036393388  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.3339433e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -3.89         |
# | fps                | 515           |
# | n_updates          | 81            |
# | policy_entropy     | 0.040354952   |
# | policy_loss        | -0.0012976492 |
# | serial_timesteps   | 10368         |
# | time_elapsed       | 20.6          |
# | total_timesteps    | 10368         |
# | value_loss         | 0.008822282   |
# --------------------------------------
# ----------------------------------------
# | approxkl           | 8.322248e-08    |
# | clipfrac           | 0.0             |
# | explained_variance | -1.42           |
# | fps                | 487             |
# | n_updates          | 82              |
# | policy_entropy     | 0.030875854     |
# | policy_loss        | -0.000106689695 |
# | serial_timesteps   | 10496           |
# | time_elapsed       | 20.8            |
# | total_timesteps    | 10496           |
# | value_loss         | 0.0021314102    |
# ----------------------------------------
# -------------------------------------
# | approxkl           | 5.012696e-06 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0607       |
# | fps                | 521          |
# | n_updates          | 83           |
# | policy_entropy     | 0.044533502  |
# | policy_loss        | -6.57856e-05 |
# | serial_timesteps   | 10624        |
# | time_elapsed       | 21.1         |
# | total_timesteps    | 10624        |
# | value_loss         | 0.58647084   |
# -------------------------------------
# ---------------------------------------
# | approxkl           | 1.4315343e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0398         |
# | fps                | 508            |
# | n_updates          | 84             |
# | policy_entropy     | 0.02824215     |
# | policy_loss        | -0.00010875589 |
# | serial_timesteps   | 10752          |
# | time_elapsed       | 21.4           |
# | total_timesteps    | 10752          |
# | value_loss         | 0.049835227    |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.1635668e-08  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0011        |
# | fps                | 500            |
# | n_updates          | 85             |
# | policy_entropy     | 0.033384982    |
# | policy_loss        | -4.8452057e-07 |
# | serial_timesteps   | 10880          |
# | time_elapsed       | 21.6           |
# | total_timesteps    | 10880          |
# | value_loss         | 2.6263373      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.0001299903  |
# | clipfrac           | 0.001953125   |
# | explained_variance | -0.13         |
# | fps                | 503           |
# | n_updates          | 86            |
# | policy_entropy     | 0.034152307   |
# | policy_loss        | -0.0045508775 |
# | serial_timesteps   | 11008         |
# | time_elapsed       | 21.9          |
# | total_timesteps    | 11008         |
# | value_loss         | 0.004423427   |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.0378892e-06 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0557        |
# | fps                | 480           |
# | n_updates          | 87            |
# | policy_entropy     | 0.024939472   |
# | policy_loss        | 5.245267e-05  |
# | serial_timesteps   | 11136         |
# | time_elapsed       | 22.1          |
# | total_timesteps    | 11136         |
# | value_loss         | 2.5138247     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 3.5807677e-09 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.0159        |
# | fps                | 488           |
# | n_updates          | 88            |
# | policy_entropy     | 0.03103941    |
# | policy_loss        | 1.1408702e-06 |
# | serial_timesteps   | 11264         |
# | time_elapsed       | 22.4          |
# | total_timesteps    | 11264         |
# | value_loss         | 1.2533728     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00045680066 |
# | clipfrac           | 0.001953125   |
# | explained_variance | -5.8          |
# | fps                | 464           |
# | n_updates          | 89            |
# | policy_entropy     | 0.037123863   |
# | policy_loss        | -0.0047012735 |
# | serial_timesteps   | 11392         |
# | time_elapsed       | 22.6          |
# | total_timesteps    | 11392         |
# | value_loss         | 0.01804613    |
# --------------------------------------
# --------------------------------------
# | approxkl           | 1.4045126e-07 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.0187       |
# | fps                | 513           |
# | n_updates          | 90            |
# | policy_entropy     | 0.02115052    |
# | policy_loss        | 2.9346673e-05 |
# | serial_timesteps   | 11520         |
# | time_elapsed       | 22.9          |
# | total_timesteps    | 11520         |
# | value_loss         | 1.6613281     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.972655e-06   |
# | clipfrac           | 0.0            |
# | explained_variance | 0.0587         |
# ...
# | value_loss         | 0.0008927388   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 2.744308e-07   |
# | clipfrac           | 0.0            |
# | explained_variance | -5.62          |
# | fps                | 486            |
# | n_updates          | 126            |
# | policy_entropy     | 0.020293549    |
# | policy_loss        | -0.00020856899 |
# | serial_timesteps   | 16128          |
# | time_elapsed       | 32.1           |
# | total_timesteps    | 16128          |
# | value_loss         | 0.0016888187   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 5.276596e-07   |
# | clipfrac           | 0.0            |
# | explained_variance | -33.9          |
# | fps                | 515            |
# | n_updates          | 127            |
# | policy_entropy     | 0.012675036    |
# | policy_loss        | -0.00033425353 |
# | serial_timesteps   | 16256          |
# | time_elapsed       | 32.3           |
# | total_timesteps    | 16256          |
# | value_loss         | 0.0010811134   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 1.6317643e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.0126        |
# | fps                | 499            |
# | n_updates          | 128            |
# | policy_entropy     | 0.017972527    |
# | policy_loss        | -0.00033539673 |
# | serial_timesteps   | 16384          |
# | time_elapsed       | 32.6           |
# | total_timesteps    | 16384          |
# | value_loss         | 1.0788792      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00025630527 |
# | clipfrac           | 0.005859375   |
# | explained_variance | -3.5          |
# | fps                | 469           |
# | n_updates          | 129           |
# | policy_entropy     | 0.012978457   |
# | policy_loss        | -0.00533851   |
# | serial_timesteps   | 16512         |
# | time_elapsed       | 32.8          |
# | total_timesteps    | 16512         |
# | value_loss         | 0.0016069894  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.448585e-09   |
# | clipfrac           | 0.0            |
# | explained_variance | -6.12          |
# | fps                | 488            |
# | n_updates          | 130            |
# | policy_entropy     | 0.012394414    |
# | policy_loss        | -2.6408932e-05 |
# | serial_timesteps   | 16640          |
# | time_elapsed       | 33.1           |
# | total_timesteps    | 16640          |
# | value_loss         | 0.0023365289   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 2.7183746e-09 |
# | clipfrac           | 0.0           |
# | explained_variance | 0.487         |
# | fps                | 491           |
# | n_updates          | 131           |
# | policy_entropy     | 0.011084713   |
# | policy_loss        | -6.640679e-06 |
# | serial_timesteps   | 16768         |
# | time_elapsed       | 33.4          |
# | total_timesteps    | 16768         |
# | value_loss         | 0.0004902375  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 6.613744e-12   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.000833      |
# | fps                | 474            |
# | n_updates          | 132            |
# | policy_entropy     | 0.008464232    |
# | policy_loss        | -1.0826625e-08 |
# | serial_timesteps   | 16896          |
# | time_elapsed       | 33.6           |
# | total_timesteps    | 16896          |
# | value_loss         | 2.7572923      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 0.00016190679 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -5.67         |
# | fps                | 502           |
# | n_updates          | 133           |
# | policy_entropy     | 0.015165213   |
# | policy_loss        | -0.0015574781 |
# | serial_timesteps   | 17024         |
# | time_elapsed       | 33.9          |
# | total_timesteps    | 17024         |
# | value_loss         | 0.0024020902  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.6331627e-07  |
# | clipfrac           | 0.0            |
# | explained_variance | -2.68          |
# | fps                | 481            |
# | n_updates          | 134            |
# | policy_entropy     | 0.014465371    |
# | policy_loss        | -0.00022122252 |
# | serial_timesteps   | 17152          |
# | time_elapsed       | 34.2           |
# | total_timesteps    | 17152          |
# | value_loss         | 0.0018352461   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 4.048181e-10  |
# | clipfrac           | 0.0           |
# | explained_variance | -13.2         |
# | fps                | 512           |
# | n_updates          | 135           |
# | policy_entropy     | 0.010132272   |
# | policy_loss        | 2.2014137e-07 |
# | serial_timesteps   | 17280         |
# | time_elapsed       | 34.4          |
# | total_timesteps    | 17280         |
# | value_loss         | 0.001302589   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.6361156e-06  |
# | clipfrac           | 0.0            |
# | explained_variance | -2.06          |
# | fps                | 484            |
# | n_updates          | 136            |
# | policy_entropy     | 0.01289928     |
# | policy_loss        | -0.00086377806 |
# | serial_timesteps   | 17408          |
# | time_elapsed       | 34.7           |
# | total_timesteps    | 17408          |
# | value_loss         | 0.0021239384   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 8.945452e-10  |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00593      |
# | fps                | 469           |
# | n_updates          | 137           |
# | policy_entropy     | 0.010719418   |
# | policy_loss        | -3.678375e-06 |
# | serial_timesteps   | 17536         |
# | time_elapsed       | 34.9          |
# | total_timesteps    | 17536         |
# | value_loss         | 2.732894      |
# --------------------------------------
# --------------------------------------
# | approxkl           | 5.3202187e-10 |
# | clipfrac           | 0.0           |
# | explained_variance | -1.71         |
# | fps                | 511           |
# | n_updates          | 138           |
# | policy_entropy     | 0.011903647   |
# | policy_loss        | -3.304449e-06 |
# | serial_timesteps   | 17664         |
# | time_elapsed       | 35.2          |
# | total_timesteps    | 17664         |
# | value_loss         | 0.0021087558  |
# --------------------------------------
# --------------------------------------
# | approxkl           | 0.00032428544 |
# | clipfrac           | 0.00390625    |
# | explained_variance | -9.75         |
# | fps                | 470           |
# | n_updates          | 139           |
# | policy_entropy     | 0.012689281   |
# | policy_loss        | -0.002417472  |
# | serial_timesteps   | 17792         |
# | time_elapsed       | 35.5          |
# | total_timesteps    | 17792         |
# | value_loss         | 0.0019915823  |
# --------------------------------------
# -------------------------------------
# | approxkl           | 3.138016e-07 |
# | clipfrac           | 0.0          |
# | explained_variance | 0.0137       |
# | fps                | 476          |
# | n_updates          | 140          |
# | policy_entropy     | 0.013631832  |
# | policy_loss        | -1.91211e-05 |
# | serial_timesteps   | 17920        |
# | time_elapsed       | 35.7         |
# | total_timesteps    | 17920        |
# | value_loss         | 1.7260324    |
# -------------------------------------
# --------------------------------------
# | approxkl           | 8.448318e-09  |
# | clipfrac           | 0.0           |
# | explained_variance | -5.94         |
# | fps                | 503           |
# | n_updates          | 141           |
# | policy_entropy     | 0.011677672   |
# | policy_loss        | -4.431384e-05 |
# | serial_timesteps   | 18048         |
# | time_elapsed       | 36            |
# | total_timesteps    | 18048         |
# | value_loss         | 0.0029609632  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 5.659701e-09   |
# | clipfrac           | 0.0            |
# | explained_variance | -0.00743       |
# | fps                | 507            |
# | n_updates          | 142            |
# | policy_entropy     | 0.012078947    |
# | policy_loss        | -1.2549572e-06 |
# | serial_timesteps   | 18176          |
# | time_elapsed       | 36.3           |
# | total_timesteps    | 18176          |
# | value_loss         | 2.707146       |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.5773586e-09 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.3          |
# | fps                | 500           |
# | n_updates          | 143           |
# | policy_entropy     | 0.009170889   |
# | policy_loss        | -9.176787e-06 |
# | serial_timesteps   | 18304         |
# | time_elapsed       | 36.5          |
# | total_timesteps    | 18304         |
# | value_loss         | 0.0027557854  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.9674946e-11  |
# | clipfrac           | 0.0            |
# | explained_variance | -0.397         |
# | fps                | 489            |
# | n_updates          | 144            |
# | policy_entropy     | 0.0077218614   |
# | policy_loss        | -1.7229468e-08 |
# | serial_timesteps   | 18432          |
# | time_elapsed       | 36.8           |
# | total_timesteps    | 18432          |
# | value_loss         | 0.002160833    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 5.968892e-12  |
# | clipfrac           | 0.0           |
# | explained_variance | 0.00466       |
# | fps                | 474           |
# | n_updates          | 145           |
# | policy_entropy     | 0.009529548   |
# | policy_loss        | 1.8859282e-07 |
# | serial_timesteps   | 18560         |
# | time_elapsed       | 37            |
# | total_timesteps    | 18560         |
# | value_loss         | 2.3038838     |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 4.444279e-10   |
# | clipfrac           | 0.0            |
# | explained_variance | -1.95          |
# | fps                | 471            |
# | n_updates          | 146            |
# | policy_entropy     | 0.010970392    |
# | policy_loss        | -3.2400712e-06 |
# | serial_timesteps   | 18688          |
# | time_elapsed       | 37.3           |
# | total_timesteps    | 18688          |
# | value_loss         | 0.0048079113   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 1.2663409e-05 |
# | clipfrac           | 0.0           |
# | explained_variance | -8.4          |
# | fps                | 469           |
# | n_updates          | 147           |
# | policy_entropy     | 0.01431382    |
# | policy_loss        | -0.0010198228 |
# | serial_timesteps   | 18816         |
# | time_elapsed       | 37.6          |
# | total_timesteps    | 18816         |
# | value_loss         | 0.0039665457  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 2.2773674e-09  |
# | clipfrac           | 0.0            |
# | explained_variance | 0.00687        |
# | fps                | 518            |
# | n_updates          | 148            |
# | policy_entropy     | 0.010117197    |
# | policy_loss        | -7.7112345e-06 |
# | serial_timesteps   | 18944          |
# | time_elapsed       | 37.9           |
# | total_timesteps    | 18944          |
# | value_loss         | 2.6855183      |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.3081935e-10 |
# | clipfrac           | 0.0           |
# | explained_variance | -5.68         |
# | fps                | 532           |
# | n_updates          | 149           |
# | policy_entropy     | 0.010359919   |
# | policy_loss        | -9.786105e-06 |
# | serial_timesteps   | 19072         |
# | time_elapsed       | 38.1          |
# | total_timesteps    | 19072         |
# | value_loss         | 0.00392071    |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 3.1495992e-09  |
# | clipfrac           | 0.0            |
# | explained_variance | -3.12          |
# | fps                | 534            |
# | n_updates          | 150            |
# | policy_entropy     | 0.010975818    |
# | policy_loss        | -3.8600992e-06 |
# | serial_timesteps   | 19200          |
# | time_elapsed       | 38.4           |
# | total_timesteps    | 19200          |
# | value_loss         | 0.002622829    |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 7.9613927e-10 |
# | clipfrac           | 0.0           |
# | explained_variance | -0.00806      |
# | fps                | 507           |
# | n_updates          | 151           |
# | policy_entropy     | 0.014129926   |
# | policy_loss        | 1.762528e-07  |
# | serial_timesteps   | 19328         |
# | time_elapsed       | 38.6          |
# | total_timesteps    | 19328         |
# | value_loss         | 7.4974236     |
# --------------------------------------
# --------------------------------------
# | approxkl           | 4.9833676e-10 |
# | clipfrac           | 0.0           |
# | explained_variance | -7.03         |
# | fps                | 502           |
# | n_updates          | 152           |
# | policy_entropy     | 0.010147527   |
# | policy_loss        | -8.665607e-06 |
# | serial_timesteps   | 19456         |
# | time_elapsed       | 38.8          |
# | total_timesteps    | 19456         |
# | value_loss         | 0.0028249878  |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.0259036e-05  |
# | clipfrac           | 0.0            |
# | explained_variance | -8.36          |
# | fps                | 504            |
# | n_updates          | 153            |
# | policy_entropy     | 0.016134243    |
# | policy_loss        | -0.00096289767 |
# | serial_timesteps   | 19584          |
# | time_elapsed       | 39.1           |
# | total_timesteps    | 19584          |
# | value_loss         | 0.0038381557   |
# ---------------------------------------
# --------------------------------------
# | approxkl           | 3.696484e-08  |
# | clipfrac           | 0.0           |
# | explained_variance | -2.03         |
# | fps                | 496           |
# | n_updates          | 154           |
# | policy_entropy     | 0.011885816   |
# | policy_loss        | -2.167793e-05 |
# | serial_timesteps   | 19712         |
# | time_elapsed       | 39.4          |
# | total_timesteps    | 19712         |
# | value_loss         | 0.002148543   |
# --------------------------------------
# ---------------------------------------
# | approxkl           | 1.216018e-08   |
# | clipfrac           | 0.0            |
# | explained_variance | -7.5           |
# | fps                | 491            |
# | n_updates          | 155            |
# | policy_entropy     | 0.0127495425   |
# | policy_loss        | -5.8253063e-05 |
# | serial_timesteps   | 19840          |
# | time_elapsed       | 39.6           |
# | total_timesteps    | 19840          |
# | value_loss         | 0.0015955035   |
# ---------------------------------------
# ---------------------------------------
# | approxkl           | 0.00012605758  |
# | clipfrac           | 0.00390625     |
# | explained_variance | -8.23          |
# | fps                | 479            |
# | n_updates          | 156            |
# | policy_entropy     | 0.011006439    |
# | policy_loss        | -0.00080624304 |
# | serial_timesteps   | 19968          |
# | time_elapsed       | 39.9           |
# | total_timesteps    | 19968          |
# | value_loss         | 0.0015748006   |
# ---------------------------------------

# %%
sum(reward_list)
# Out:
# array([-0.90000015], dtype=float32)

# %% [markdown]
# ## Random Model

# %%
reward_list = []
for i in range(500): 
    obs = env.reset()
    action = np.random.choice([0,1], size=1)
    obs, rewards, done, info = env.step(action)
    reward_list.append(rewards)

# %%
sum(reward_list)
# Out:
# array([-12.250029], dtype=float32)
